# %% [markdown]
# # Vetorização dos CSV

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
import chromadb
import uuid
import csv

# %% [markdown]
# ### Estabelecendo conexão com o chromadb

# %%
# client = chromadb.Client()
client = chromadb.PersistentClient(path="../../../docs/my_db")

# %% [markdown]
# ### Criando/Carregando Collections

# %%
nutrition = client.get_or_create_collection(name="nutrition")

# %% [markdown]
# ### Carregando Arquivos

# %% [markdown]
# #### Tabela TACO

# %%
taco_rows = []

with open("../../../docs/datasets/formattedTACO.csv", "r", encoding="utf-8") as f:
    reader = csv.DictReader(f)  # lê como dicionários
    for row in reader:
        # transforma a linha em texto descritivo
        taco_rows.append(row)

taco_chunks = []

for row in taco_rows:
    chunk = ""
    #for key in row.keys():
    #    chunk += " " + str(key) # chave
    #    chunk += ": " + str(row[key]) + "," # valor
    chunk += f"O alimento {row['nome']} tem {row['umidade_(%)']}% de umidade, {row['energia_(kcal)']}kcal de energia, {row['energia_(kj)']}kj de energia, {row['proteina_(g)']}g de proteína, {row['lipideos_(g)']}g de lipídeos, {row['colesterol_(mg)']}mg de colesterol, {row['carboidrato_(g)']}g de carboídrato, {row['fibra_alimentar_(g)']}g de fibra alimentar, {row['cinzas_(g)']}g de cinzas, {row['calcio_(mg)']}mg de cálcio e {row['magnesio_(mg)']}mg de magnésio"
    taco_chunks.append(chunk)

print(taco_chunks)
# Out:
# ['O alimento arroz integral cozido tem 70.1% de umidade, 124kcal de energia, 517kj de energia, 2.6g de proteína, 1.0g de lipídeos, 0mg de colesterol, 25.8g de carboídrato, 2.7g de fibra alimentar, 0.5g de cinzas, 5mg de cálcio e 59 mg de magnésio', 'O alimento arroz integral cru tem 12.2% de umidade, 360kcal de energia, 1505kj de energia, 7.3g de proteína, 1.9g de lipídeos, 0mg de colesterol, 77.5g de carboídrato, 4.8g de fibra alimentar, 1.2g de cinzas, 8mg de cálcio e 110 mg de magnésio', 'O alimento arroz tipo 1 cozido tem 69.1% de umidade, 128kcal de energia, 537kj de energia, 2.5g de proteína, 0.2g de lipídeos, 0mg de colesterol, 28.1g de carboídrato, 1.6g de fibra alimentar, 0.1g de cinzas, 4mg de cálcio e 2 mg de magnésio', 'O alimento arroz tipo 1 cru tem 13.2% de umidade, 358kcal de energia, 1497kj de energia, 7.2g de proteína, 0.3g de lipídeos, 0mg de colesterol, 78.8g de carboídrato, 1.6g de fibra alimentar, 0.5g de cinzas, 4mg de cálcio e 30 mg de magnésio', 'O alimento arroz tipo 2 cozido tem 68.7% de umidade, 130kcal de energia, 544kj de energia, 2.6g de proteína, 0.4g de lipídeos, 0mg de colesterol, 28.2g de carboídrato, 1.1g de fibra alimentar, 0.1g de cinzas, 3mg de cálcio e 6 mg de magnésio', 'O alimento arroz tipo 2 cru tem 13.2% de umidade, 358kcal de energia, 1498kj de energia, 7.2g de proteína, 0.3g de lipídeos, 0mg de colesterol, 78.9g de carboídrato, 1.7g de fibra alimentar, 0.4g de cinzas, 5mg de cálcio e 29mg de magnésio', 'O alimento  aveia flocos crua tem  9.1% de umidade,  394kcal de energia,  1648kj de energia,  13.9g de proteína,  8.5g de lipídeos, 0mg de colesterol,  66.6g de carboídrato,  9.1g de fibra alimentar,  1.8g de cinzas,  48mg de cálcio e  119mg de magnésio', 'O alimento  biscoito doce maisena tem  3.2% de umidade,  443kcal de energia,  1853kj de energia,  8.1g de proteína,  12.0g de lipídeos, 0mg de colesterol,  75.2g de carboídrato,  2.1g de fibra alimentar,  1.5g de cinzas,  54mg de cálcio e  37mg de magnésio', 'O alimento  biscoito doce recheado com chocolate tem  2.2% de umidade,  472kcal de energia,  1974kj de energia,  6.4g de proteína,  19.6g de lipídeos, 0mg de colesterol,  70.5g de carboídrato,  3.0g de fibra alimentar,  1.3g de cinzas,  27mg de cálcio e  48mg de magnésio', 'O alimento  biscoito doce recheado com morango tem  2.7% de umidade,  471kcal de energia,  1971kj de energia,  5.7g de proteína,  19.6g de lipídeos, 0mg de colesterol,  71.0g de carboídrato,  1.5g de fibra alimentar,  1.0g de cinzas,  36mg de cálcio e  27mg de magnésio', 'O alimento  biscoito doce wafer recheado de chocolate tem  1.2% de umidade,  502kcal de energia,  2102kj de energia,  5.6g de proteína,  24.7g de lipídeos, 0mg de colesterol,  67.5g de carboídrato,  1.8g de fibra alimentar,  1.1g de cinzas,  23mg de cálcio e  48mg de magnésio', 'O alimento  biscoito doce wafer recheado de morango tem  1.2% de umidade,  513kcal de energia,  2148kj de energia,  4.5g de proteína,  26.4g de lipídeos,  1mg de colesterol,  67.4g de carboídrato,  0.8g de fibra alimentar,  0.6g de cinzas,  14mg de cálcio e  19mg de magnésio', 'O alimento  biscoito salgado cream cracker tem  4.1% de umidade,  432kcal de energia,  1806kj de energia,  10.1g de proteína,  14.4g de lipídeos, 0mg de colesterol,  68.7g de carboídrato,  2.5g de fibra alimentar,  2.7g de cinzas,  20mg de cálcio e  40mg de magnésio', 'O alimento  bolo mistura para tem  1.0% de umidade,  419kcal de energia,  1752kj de energia,  6.2g de proteína,  6.1g de lipídeos, 0mg de colesterol,  84.7g de carboídrato,  1.7g de fibra alimentar,  2.0g de cinzas,  59mg de cálcio e  28mg de magnésio', 'O alimento  bolo pronto aipim tem  34.1% de umidade,  324kcal de energia,  1355kj de energia,  4.4g de proteína,  12.7g de lipídeos,  73mg de colesterol,  47.9g de carboídrato,  0.7g de fibra alimentar,  0.8g de cinzas,  85mg de cálcio e  10mg de magnésio', 'O alimento  bolo pronto chocolate tem  19.3% de umidade,  410kcal de energia,  1715kj de energia,  6.2g de proteína,   ...

# %% [markdown]
# #### Tabela TBCA

# %%
tbca_rows = []

with open("../../../docs/datasets/formattedTBCA.csv", "r", encoding="utf-8") as f:
    reader = csv.DictReader(f, delimiter=";")  # lê como dicionários
    for row in reader:
        # transforma a linha em texto descritivo
        tbca_rows.append(row)

tbca_chunks = []

for row in tbca_rows:
    chunk = ""
    #for key in row.keys():
    #    chunk += " " + str(key) # chave
    #    chunk += ": " + str(row[key]) + "," # valor
    chunk += f"O alimento {row['alimento'].replace(",", "").strip()} tem {row['energia_kj']}kj de energia, {row['energia_kcal']}kcal de energia, {row['umidade_g']}g de umidade, {row['carboidrato_total']}g de carboidrato total, {row['carboidrato_disponivel']}g de carboidrato disponivel, {row['proteina']}g de proteina, {row['lipidios']}g de lipidios, {row['fibra_alimentar']}g de fibra alimentar, {row['alcool']}g de alcool, {row['cinzas']}g de cinzas, {row['colesterol']}mg de colesterol, {row['acidos_graxos_saturados']}g de acidos graxos saturados, {row['acidos_graxos_monoinsaturados']}g de acidos graxos monoinsaturados, {row['acidos_graxos_polinsaturados']}g de acidos graxos polinsaturados, {row['acidos_graxos_trans']}g de acidos graxos trans, {row['calcio']}mg de calcio, {row['ferro']}mg de ferro, {row['sodio']}mg de sodio, {row['magnesio']}mg de magnesio, {row['fosforo']}mg de fosforo, {row['potassio']}mg de potassio, {row['zinco']}mg de zinco, {row['cobre']}mg de cobre, {row['selenio']}mcg de selenio, {row['vitamina_a_(re)']}mcg de vitamina a(re), {row['vitamina_a_(rae)']}mcg de vitamina a(rae), {row['vitamina_d']}mcg de vitamina d, {row['alfa-tocoferol_(vitamina_e)']}mg de alfa tocoferol ou vitamina e, {row['tiamina']}mg de tiamina, {row['riboflavina']}mg de riboflavina, {row['niacina']}mg de niacina, {row['vitamina_b6']}mg de vitamina b6, {row['vitamina_b12']}mcg de vitamina b12, {row['vitamina_c']}mg de vitamina c, {row['equivalente_de_folato']}mcg de equivalente de folato, {row['sal_de_adicao']}g de sal de adicao, {row['acucar_de_adicao']}g de acucar de adicao"
    tbca_chunks.append(chunk)

print(tbca_chunks[0])
# Out:
# O alimento oleo abacate persea americana tem 3700.0kj de energia, 900.0kcal de energia, 0g de umidade, 0g de carboidrato total, 0g de carboidrato disponivel, 0g de proteina, 100g de lipidios, 0g de fibra alimentar, 0g de alcool, 0g de cinzas, 0mg de colesterol, 20,4g de acidos graxos saturados, 67,7g de acidos graxos monoinsaturados, 11,7g de acidos graxos polinsaturados, 0g de acidos graxos trans, 0mg de calcio, 0mg de ferro, 0mg de sodio, 0mg de magnesio, 0mg de fosforo, 0mg de potassio, 0mg de zinco, 0mg de cobre, 0mcg de selenio, 0mcg de vitamina a(re), 0mcg de vitamina a(rae), 0mcg de vitamina d, 0mg de alfa tocoferol ou vitamina e, 0mg de tiamina, 0mg de riboflavina, 0mg de niacina, 0mg de vitamina b6, 0mcg de vitamina b12, 0mg de vitamina c, 0mcg de equivalente de folato, 0g de sal de adicao, 0g de acucar de adicao

# %% [markdown]
# ### Embeddings

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-MiniLM-L6-v2')

taco_embeddings = model.encode(taco_chunks, convert_to_numpy=True)
print(f"Embeddings gerados: {taco_embeddings.shape}")
tbca_embeddings = model.encode(tbca_chunks, convert_to_numpy=True)
print(f"Embeddings gerados: {tbca_embeddings.shape}")
# Out:
# Embeddings gerados: (597, 384)
# Embeddings gerados: (5268, 384)

# %% [markdown]
# ### Adicionando coleções

# %%
# TACO
nutrition.add(
    ids=[str(uuid.uuid4()) for _ in taco_chunks],
    documents=taco_chunks,
    embeddings=taco_embeddings,
    metadatas=[{"origem":"taco"} for _ in taco_chunks]
)
# TBCA
nutrition.add(
    ids=[str(uuid.uuid4()) for _ in tbca_chunks],
    documents=tbca_chunks,
    embeddings=tbca_embeddings,
    metadatas=[{"origem": "tbca"} for _ in tbca_chunks]
)

# %% [markdown]
# ### Queries de teste

# %%
#import numpy as np

results = nutrition.query(
    query_texts=[
        "Quanto de proteína tem o arroz integral cru?",
        "Quanto de carboidrato tem o biscoito doce maisena?",
        "Qual alimento possui mais magnésio?",
        "Qual alimento tem maior fibra alimentar?"
